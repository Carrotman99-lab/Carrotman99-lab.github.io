# %% [markdown]
# # SWCON104-00 Web/Python Programming 2021-1 Midterm Assignment

# %% [markdown]
# - 답안지 작성시 파일이름을 '학번이름.ipynb'으로 변경하여 e-campus에 제출하시오. 답안파일만 제출하시오. (예:2020101234홍길동.ipynb)
#
# - 제출기한: 4월23일 23시59분
#
# - 각 셀당 점수가 배정되어 있으며 셀을 실행하여 syntax error가 발생하거나 실행되지 않으면 해당 셀의 점수는 0점입니다.
#
# - 셀마다 함수헤더가 주어져있습니다. 이를 절대 변경하지 마세요. 또한, 문제에서 명시한 함수 이외에 추가 함수를 구현하지 마세요.
#
# - 채점은 코드를 읽어서 채점하지 않고, 해당 함수에 여러 입력파라미터를 넣어 각각의 경우에 반환값이 정확하게 나오는지를 자동프로그램으로 채점합니다. 여러 케이스를 테스트하여 케이스가 맞는 갯수에 따라 점수가 결정됩니다. 따라서 셀이 실행되지 않거나 함수헤더가 틀리거나 반환값의 type이 틀리면 해당 셀은 0점처리 됩니다. 유의하세요.
#
# - 실행예시 외에도 다양한 케이스를 활용하여 채점합니다. 즉, 실행예시가 똑같이 나온다고 해서 만점이라는 보장은 없습니다. 문제지의 조건을 모두 만족하는 함수를 구현해야만 합니다.
#
# - 문제지에 주어지는 가정들은 문제가 너무 어려워지는 것을 방지하기 위해 만든 일종의 제한선입니다. 가정에서 벗어나는 케이스들은 채점시 테스트하지 않습니다.
#
# - This file should be renamed as 'IDYourName.ipynb' and submitted to e-campus. Submit this file only. (Ex:2020101234HongGildong.ipynb)
#
# - Submission deadline: April 23rd 23:59 pm
#
# - The score is assigned to each cell. If a cell makes a syntax error or if it is not executed at all, the score for the cell is zero.
#
# - A function header is given for each cell. Do not change the function header. Do not implement additional functions.
#
# - This file will be graded by checking many input-return pairs to the functions automatically. Your score will be determined by the number of correct return values to the test inputs. Therefore, if a cell is not executed or has a wrong function header, or if a function returns a value of wrong type, the score for the cell is zero. Be careful.
#
# - Your functions will be tested by many input-return pairs in addition to the ones in execution examples given below. Thus, your score may not be a perfect score even though you checked the same output as execution examples. Your functions must satisfy all the conditions as stated in the problem.
#
# - Assumptions in the problems are restriction to prevent the problem from being too difficult. Input-return pairs beyond the assumptions will not be tested.

# %% [markdown]
# ## [문제1] (4점)

# %%
def morse_to_num(morse):  #[4점]
    
    count = len(morse)//5
    
    
    if count == 1:
        
        if '*' == morse[0]:
            x = morse.count('*',0,5)
            
            return x
            
        elif '-' == morse[0]:
            
            y = morse.count('*',0,5)
            
            return (10-y)%10
     
    if count == 2:
        
        if '*' == morse[0]:
            x = morse.count('*',0,5)*10
           
            if '*' == morse[5]:
                y = morse.count('*',5,10)
                
                return x+y
      
    # (str) -> int
    # Implement the function here. Do not change the function header
    
print(morse_to_num('****-'))
print(morse_to_num('****-*----'))
# Out:
# 4
# 41

# %%
# 이 셀을 실행하면 실행예시와 동일한 출력이 나와야 한다. 
# If you run this cell, you should get the same output as below screenshot.
print(morse_to_num('****-'))
print(morse_to_num('*****--***'))
print(morse_to_num('----*----*----*'))
print(morse_to_num('*----**---***---****'))
print(morse_to_num('----*----*---**---**-----'))
print(morse_to_num('----*----*---**---**----------'))

# %% [markdown]
# #### 아래는 문제1 실행예시 스크린샷입니다. This is the execution example screenshot of Problem 1.
# ![mid1-wp21-1.jpg](attachment:mid1-wp21-1.jpg)

# %% [markdown]
# ## [문제2] (16점)

# %%
def is_leap_year(year): #[3점]
    # (int) -> bool
    # Implement the function here. Do not change the function header

# %%
def month_list(year):  #[3점]
    # (int) -> List
    # Implement the function here. Do not change the function header

# %%
def how_many_days(A,B):  #[5점]
    # (List,List) -> int
    # Implement the function here. Do not change the function header

# %%
def days_after(date, days):  #[5점]
    # (List,int) -> List
    # Implement the function here. Do not change the function header

# %%
# 이 셀을 실행하면 실행예시와 동일한 출력이 나와야 한다. 
# If you run this cell, you should get the same output as below screenshot.
print(is_leap_year(1900))
print(is_leap_year(2000))
print(is_leap_year(2020))
print(is_leap_year(2021))
print(month_list(1900))
print(month_list(2000))
print(month_list(2020))
print(month_list(2021))
print(how_many_days([2021,4,23],[2021,4,25]))
print(how_many_days([2021,9,17],[2021,12,25]))
print(how_many_days([1998,1,29],[2148,2,28]))
print(days_after([2021,4,23],1))
print(days_after([2021,4,23],99999))
print(days_after([1988,5,31],84677))

# %% [markdown]
# #### 아래는 문제2 실행예시 스크린샷입니다. This is the execution example screenshot of Problem 2.
# ![mid2-wp21-1.jpg](attachment:mid2-wp21-1.jpg)
